# %% [markdown]
# # PROJECT-1 : HEART DISEASE PREDICTION

# %% [markdown]
# ## Import libraries

# %%
#Libraries which is used in this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv("Heart_disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Data exploration

# %% [markdown]
# #### 1. Display basic information

# %%
# Display basic information
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df['target'].value_counts().plot(kind='bar',color=['green', 'blue'])
plt.show()

# %%
# Summary statistics
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ## Checking for null values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #### IF the null value exists then we fill by using this :

# %%
df.fillna(df.median(), inplace=True)

# %% [markdown]
# ## Check for dublicate values

# %%
# Count total duplicate rows
duplicates_count = df.duplicated().sum()
print(f"Total duplicate rows: {duplicates_count}")
# Out:
# Total duplicate rows: 1

# %% [markdown]
# #### Remove dublicate if exists

# %%
# Remove duplicates
df_cleaned = df.drop_duplicates()

# Confirm removal
print(f"Total duplicate rows after cleaning: {df_cleaned.duplicated().sum()}")
# Out:
# Total duplicate rows after cleaning: 0

# %% [markdown]
# #### Saved the clean file

# %%
df_cleaned.to_csv('cleaned_heart_disease_data.csv', index=False)

# %%
df1=pd.read_csv('cleaned_heart_disease_data.csv')

# %%
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ### 1. Target Variable Distribution

# %%
sns.countplot(x='target', data=df1)
plt.title("Heart Disease Presence (1) vs Absence (0)")
plt.show()

# %% [markdown]
# ### 2. Histograms of Features

# %%
df1.hist(figsize=(12, 10), bins=20)
plt.show()

# %% [markdown]
# ### 3. Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm',fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 4. Boxplots for Outlier Detection

# %%
for column in df1.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df1[column])
    plt.title(f"Boxplot for {column}")
    plt.show()

# %%
# Checking numerical columns
numerical_columns = df1.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Columns:", numerical_columns)
# Out:
# Numerical Columns: Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# #### Box plot before removing outliers

# %%
# Boxplot before removing outliers
plt.figure(figsize=(15, 6))
sns.boxplot(data=df1)
plt.xticks(rotation=90)
plt.title('Boxplot - After Outlier Removal')
plt.show()

# %% [markdown]
# ## Check the accuracy of model with outliers

# %%
df2=df1
df2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# ### Split the data into training and testing sets

# %%
# splitting
X = df.drop('target', axis=1)
y = df['target']
np.random.seed(42)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train), len(y_train)
# Out:
# (242, 242)

# %% [markdown]
# ### Make  the model for check the accuracy
# #### In which use following algorithms for check the accuracy
# #### "Logistic Regression":
# #### "KNN":
# #### "Random Forest":

# %%
# Make a dictionary of models
models = {
    "Logistic Regression":LogisticRegression(),
    "KNN":KNeighborsClassifier(),
    "Random Forest":RandomForestClassifier()
}

# Function to fit the models and test them
def fit_score(models, X_train, X_test, y_train, y_test):
    
    np.random.seed(42)
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %% [markdown]
# #### Accuracy of the model

# %%
fit_score(models, X_train, X_test, y_train, y_test)
# Out:
# C:\Users\windows 10\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'Logistic Regression': 0.8852459016393442,
#  'KNN': 0.6885245901639344,
#  'Random Forest': 0.8360655737704918}

# %%
log_reg = LogisticRegression()
dec_tree = DecisionTreeClassifier()
rand_forest = RandomForestClassifier()
knn = KNeighborsClassifier()

# Train models
log_reg.fit(X_train, y_train)
dec_tree.fit(X_train, y_train)
rand_forest.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# C:\Users\windows 10\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# Predict on test data
y_pred_log = log_reg.predict(X_test)
y_pred_tree = dec_tree.predict(X_test)
y_pred_forest = rand_forest.predict(X_test)
y_pred_knn = knn.predict(X_test)

# Performance metrics function
def evaluate_model(y_test, y_pred, model_name):
    print(f"\nPerformance Report for {model_name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("AUC-ROC Score:", roc_auc_score(y_test, y_pred))

# Evaluate models
evaluate_model(y_test, y_pred_log, "Logistic Regression")
evaluate_model(y_test, y_pred_tree, "Decision Tree")
evaluate_model(y_test, y_pred_forest, "Random Forest")
evaluate_model(y_test, y_pred_knn, "knn")
# Out:
# Performance Report for Logistic Regression
# Accuracy: 0.8852459016393442
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61
#
# AUC-ROC Score: 0.8841594827586207
#
# Performance Report for Decision Tree
# Accuracy: 0.8524590163934426
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86        29
#            1       0.93      0.78      0.85        32
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.86      0.85        61
# weighted avg       0.86      0.85      0.85        61
#
# AUC-ROC Score: 0.8561422413793104
#
# Performance Report for Random Forest
# Accuracy: 0.8524590163934426
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        29
#            1       0.85      0.88      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
# AUC-ROC Score: 0.8512931034482758
#
# Performance Report for knn
# Accuracy: 0.6885245901639344
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.62      0.65        29
#            1       0.69      0.75      0.72        32
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# AUC-ROC Score: 0.6853448275862069

# %%
#Acuracy graph
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

# Collect accuracy scores for each model
accuracy_scores = {
    "Logistic Regression": accuracy_score(y_test, y_pred_log),
    "Decision Tree": accuracy_score(y_test, y_pred_tree),
    "Random Forest": accuracy_score(y_test, y_pred_forest),
    "knn":accuracy_score(y_test, y_pred_knn),
    "scv": metrics.accuracy_score(y_test,y_pred_svc)
}

# Plotting the accuracy chart
fig, ax = plt.subplots(figsize=(8, 5))
models = list(accuracy_scores.keys())
scores = list(accuracy_scores.values())

# Create bar chart

ax.bar(models, scores, color=['blue', 'green', 'orange','red'])
ax.set_title('Model Accuracy Comparison')
ax.set_xlabel('Models')
ax.set_ylabel('Accuracy Score')
ax.set_ylim(0, 1)
ax.bar_label(ax.containers[0])

# Display the plot
plt.show()

# %% [markdown]
# ### Draw the bar plot for better visualization

# %%
model_compare = pd.DataFrame(fit_score(models, X_train, X_test, y_train, y_test), index=['accuracy'])
model_compare.T.plot.bar()
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 model_compare = pd.DataFrame(fit_score(models, X_train, X_test, y_train, y_test), index=['accuracy'])
#       2 model_compare.T.plot.bar()
#       3 plt.xticks(rotation=0)
#
# Cell In[25], line 13, in fit_score(models, X_train, X_test, y_train, y_test)
#      11 np.random.seed(42)
#      12 model_scores = {}
# ---> 13 for name, model in models.items():
#      14     model.fit(X_train, y_train)
#      15     model_scores[name] = model.score(X_test, y_test)
#
# AttributeError: 'list' object has no attribute 'items'

# %% [markdown]
# ### SVC model accuracy check

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc= SVC(kernel='linear')
 # kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} 
svc.fit(X_train,y_train)
 
y_pred_svc = svc.predict(X_test)
 
print("Accuracy of svc classifier :: ", metrics.accuracy_score(y_test,y_pred_svc))
# Out:
# Accuracy of svc classifier ::  0.8688524590163934

# %% [markdown]
# ## Check the performance after removing the outliers

# %% [markdown]
# ### > Use the IQR method to remove the outliers

# %%
#Remove the outlier
#calculate IQR
q3=df1['trestbps'].quantile(.75)
q3
q1=df1['trestbps'].quantile(.25)
q1
#find value of iqr
iqr=q3-q1
iqr
#calculate upper and lower limit from iqr
ul=q3+(1.5*iqr)
ll=q1-(1.5*iqr)
print(ul,ll)
#upper bound
upper=np.where(df1['trestbps']>=ul)
#lower limit
lower=np.where(df1['trestbps']<=ll)
#delete the rows above and below lower values
df1.drop(upper[0],inplace=True)
df1.drop(lower[0],inplace=True)
#shape how many rows removed
df1.shape
#first convert trestbps value in array
arr=df2['trestbps'].values
#if value are in b/n ul and ll represent that values as ture
true_index=(ll<arr)&(arr<ul)
true_index
#so calculate the median of all values other then the ouliers
mid = np.median(df2['trestbps'][true_index])
mid
#replace all ouliers with median values
false_index = ~ true_index
df2['trestbps'].values[false_index] = mid
df2
# Out:
# 170.0 90.0
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [281 rows x 14 columns]

# %%
#Remove the outlier
#calculate IQR
q3=df1['chol'].quantile(.75)
q3
q1=df1['chol'].quantile(.25)
q1
#find value of iqr
iqr=q3-q1
iqr
#calculate upper and lower limit from iqr
ul=q3+(1.5*iqr)
ll=q1-(1.5*iqr)
print(ul,ll)
#upper bound
upper=np.where(df1['chol']>=ul)
#lower limit
lower=np.where(df1['chol']<=ll)
#delete the rows above and below lower values
df1.drop(upper[0],inplace=True)
df1.drop(lower[0],inplace=True)
#shape how many rows removed
df1.shape
#first convert cholvalue in array
arr=df2['chol'].values
#if value are in b/n ul and ll represent that values as ture
true_index=(ll<arr)&(arr<ul)
true_index
#so calculate the median of all values other then the ouliers
mid = np.median(df2['chol'][true_index])
mid
#replace all ouliers with median values
false_index = ~ true_index
df2['chol'].values[false_index] = mid
df2
# Out:
# 357.5 121.5
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [280 rows x 14 columns]

# %%
#Remove the outlier
#calculate IQR
q3=df1['thalach'].quantile(.75)
q3
q1=df1['thalach'].quantile(.25)
q1
#find value of iqr
iqr=q3-q1
iqr
#calculate upper and lower limit from iqr
ul=q3+(1.5*iqr)
ll=q1-(1.5*iqr)
print(ul,ll)
#upper bound
upper=np.where(df1['thalach']>=ul)
#lower limit
lower=np.where(df1['thalach']<=ll)
#delete the rows above and below lower values
df1.drop(upper[0],inplace=True)
df1.drop(lower[0],inplace=True)
#shape how many rows removed
df1.shape
#first convert fbs value in array
arr=df2['thalach'].values
#if value are in b/n ul and ll represent that values as ture
true_index=(ll<arr)&(arr<ul)
true_index
#so calculate the median of all values other then the ouliers
mid = np.median(df2['thalach'][true_index])
mid
#replace all ouliers with median values
false_index = ~ true_index
df2['thalach'].values[false_index] = mid
df2
# Out:
# 215.0 85.0
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [280 rows x 14 columns]

# %%
#Remove the outlier
#calculate IQR
q3=df1['thal'].quantile(.75)
q3
q1=df1['thal'].quantile(.25)
q1
#find value of iqr
iqr=q3-q1
iqr
#calculate upper and lower limit from iqr
ul=q3+(1.5*iqr)
ll=q1-(1.5*iqr)
print(ul,ll)
#upper bound
upper=np.where(df1['thal']>=ul)
#lower limit
lower=np.where(df1['thal']<=ll)
#delete the rows above and below lower values
df1.drop(upper[0],inplace=True)
df1.drop(lower[0],inplace=True)
#shape how many rows removed
df1.shape
#first convert trestbps value in array
arr=df2['thal'].values
#if value are in b/n ul and ll represent that values as ture
true_index=(ll<arr)&(arr<ul)
true_index
#so calculate the median of all values other then the ouliers
mid = np.median(df2['thal'][true_index])
mid
#replace all ouliers with median values
false_index = ~ true_index
df2['thal'].values[false_index] = mid
df2
# Out:
# 4.5 0.5
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   57    0   0       140   241    0        1      123      1      0.2
# 298   45    1   3       110   264    0        1      132      0      1.2
# 299   68    1   0       144   193    1        1      141      0      3.4
# 300   57    1   0       130   131    0        1      115      1      1.2
# 301   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 297      1   0     3       0
# 298      1   0     3       0
# 299      1   2     3       0
# 300      1   1     3       0
# 301      1   1     2       0
#
# [280 rows x 14 columns]

# %% [markdown]
# ### Boxplot after removing the outliers

# %%
# Checking if there are any remaining outliers
plt.figure(figsize=(15, 6))
sns.boxplot(data=df2)
plt.xticks(rotation=90)
plt.title('Boxplot - After Outlier Removal')
plt.show()

# %% [markdown]
# ### Split clean data in training and testing sets

# %%
# # Assuming 'target' is the label column
X_clean = df2.drop('target', axis=1)
y_clean = df2['target']

# # Feature scaling
scaler = StandardScaler()
X_clean= scaler.fit_transform(X_clean)

# %%
X_train_clean, X_test_clean, y_train_clean, y_test_clean = train_test_split(X_clean, y_clean, test_size=0.2, random_state=42)

# %% [markdown]
# ## Alorithms are used to find the accuracy of cleaned data

# %% [markdown]
# ### > SVC for calculate the accuracy

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc= SVC(kernel='linear')
 # kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} 
svc.fit(X_train_clean,y_train_clean)
 
y_pred_svc_clean = svc.predict(X_test_clean)
 
print("Accuracy of svc classifier :: ", metrics.accuracy_score(y_test_clean,y_pred_svc_clean))
# Out:
# Accuracy of svc classifier ::  0.8392857142857143

# %% [markdown]
# #### In which use following algorithms for check the accuracy
# #### "Logistic Regression":
# #### "KNN":
# #### "Random Forest":

# %%
# Make a dictionary of models
models = {
    "Logistic Regression":LogisticRegression(),
    "KNN":KNeighborsClassifier(),
    "Random Forest":RandomForestClassifier()
}

# Function to fit the models and test them
def fit_score_clean(models, X_train_clean, X_test_clean, y_train_clean, y_test_clean):
    
    np.random.seed(42)
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train_clean, y_train_clean)
        model_scores[name] = model.score(X_test_clean, y_test_clean)
    return model_scores

# %%
fit_score_clean(models, X_train_clean, X_test_clean, y_train_clean, y_test_clean)
# Out:
# {'Logistic Regression': 0.8214285714285714,
#  'KNN': 0.8571428571428571,
#  'Random Forest': 0.8214285714285714}

# %% [markdown]
# #### Draw the Bar plot for better visualization

# %%
model_compare = pd.DataFrame(fit_score_clean(models, X_train_clean, X_test_clean, y_train_clean, y_test_clean), index=['accuracy'])
model_compare.T.plot.bar()
plt.xticks(rotation=0)
plt.show()

# %%
# Train the model

log_reg_clean = LogisticRegression()
dec_tree_clean = DecisionTreeClassifier()
rand_forest_clean = RandomForestClassifier()
knn_clean = KNeighborsClassifier()

# Train models
log_reg_clean.fit(X_train_clean, y_train_clean)
dec_tree_clean.fit(X_train_clean, y_train_clean)
rand_forest_clean.fit(X_train_clean, y_train_clean)
knn_clean.fit(X_train_clean, y_train_clean)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# Predict on test data
y_pred_log_clean = log_reg_clean.predict(X_test_clean)
y_pred_tree_clean = dec_tree_clean.predict(X_test_clean)
y_pred_forest_clean = rand_forest_clean.predict(X_test_clean)
y_pred_knn_clean = knn_clean.predict(X_test_clean)

# Performance metrics function
def evaluate_model1(y_test_clean, y_pred_clean, model_name):
    print(f"\nPerformance Report for {model_name}")
    print("Accuracy:", accuracy_score(y_test_clean, y_pred_clean))
    print("Classification Report:\n", classification_report(y_test_clean, y_pred_clean))
    print("AUC-ROC Score:", roc_auc_score(y_test_clean, y_pred_clean))

# Evaluate models
evaluate_model1(y_test_clean, y_pred_log_clean, "Logistic Regression")
evaluate_model1(y_test_clean, y_pred_tree_clean, "Decision Tree")
evaluate_model1(y_test_clean, y_pred_forest_clean, "Random Forest")
evaluate_model1(y_test_clean, y_pred_knn_clean, "knn")
# Out:
# Performance Report for Logistic Regression
# Accuracy: 0.8214285714285714
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        22
#            1       0.83      0.88      0.86        34
#
#     accuracy                           0.82        56
#    macro avg       0.82      0.80      0.81        56
# weighted avg       0.82      0.82      0.82        56
#
# AUC-ROC Score: 0.8048128342245988
#
# Performance Report for Decision Tree
# Accuracy: 0.75
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.82      0.72        22
#            1       0.86      0.71      0.77        34
#
#     accuracy                           0.75        56
#    macro avg       0.75      0.76      0.75        56
# weighted avg       0.77      0.75      0.75        56
#
# AUC-ROC Score: 0.7620320855614974
#
# Performance Report for Random Forest
# Accuracy: 0.8035714285714286
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76        22
#            1       0.85      0.82      0.84        34
#
#     accuracy                           0.80        56
#    macro avg       0.79      0.80      0.80        56
# weighted avg       0.81      0.80      0.80        56
#
# AUC-ROC Score: 0.7981283422459893
#
# Performance Report for knn
# Accuracy: 0.8571428571428571
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        22
#            1       0.84      0.94      0.89        34
#
#     accuracy                           0.86        56
#    macro avg       0.87      0.83      0.84        56
# weighted avg       0.86      0.86      0.85        56
#
# AUC-ROC Score: 0.8342245989304813

# %%
#Acuracy graph
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

# Collect accuracy scores for each model
accuracy_scores = {
    "Logistic Regression": accuracy_score(y_test_clean, y_pred_log_clean),
    "Decision Tree": accuracy_score(y_test_clean, y_pred_tree_clean),
    "Random Forest": accuracy_score(y_test_clean, y_pred_forest_clean),
    "knn":accuracy_score(y_test_clean, y_pred_knn_clean),
    "SVC": metrics.accuracy_score(y_test_clean,y_pred_svc_clean)
}

# Plotting the accuracy chart
fig, ax = plt.subplots(figsize=(8, 5))
models = list(accuracy_scores.keys())
scores = list(accuracy_scores.values())

# Create bar chart
ax.bar(models, scores, color=['blue', 'green', 'orange','red'])
ax.set_title('Model Accuracy Comparison')
ax.set_xlabel('Models')
ax.set_ylabel('Accuracy Score')
ax.set_ylim(0, 1)
ax.bar_label(ax.containers[0])

# Display the plot
plt.savefig('new1.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Accuracy scores BEFORE cleaning
accuracy_scores_before = {
    "Logistic Regression": accuracy_score(y_test, y_pred_log),
    "Decision Tree": accuracy_score(y_test, y_pred_tree),
    "Random Forest": accuracy_score(y_test, y_pred_forest),
    "KNN": accuracy_score(y_test, y_pred_knn),
    "SVC": metrics.accuracy_score(y_test, y_pred_svc)
}

# Accuracy scores AFTER cleaning
accuracy_scores_after = {
    "Logistic Regression": accuracy_score(y_test_clean, y_pred_log_clean),
    "Decision Tree": accuracy_score(y_test_clean, y_pred_tree_clean),
    "Random Forest": accuracy_score(y_test_clean, y_pred_forest_clean),
    "KNN": accuracy_score(y_test_clean, y_pred_knn_clean),
    "SVC": metrics.accuracy_score(y_test_clean, y_pred_svc_clean)
}

labels = list(accuracy_scores_before.keys())
before_scores = list(accuracy_scores_before.values())
after_scores = list(accuracy_scores_after.values())

x = np.arange(len(labels))  # label locations
width = 0.35  # bar width

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width/2, before_scores, width, label='Before Cleaning', color='gray')
bars2 = ax.bar(x + width/2, after_scores, width, label='After Cleaning', color='skyblue')

# Labels, titles, and formatting
ax.set_ylabel('Accuracy Score')
ax.set_title('Model Accuracy Comparison Before vs After Data Cleaning')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(0, 1)
ax.legend()

# Add value labels to bars
ax.bar_label(bars1, fmt='%.2f', padding=3)
ax.bar_label(bars2, fmt='%.2f', padding=3)

plt.tight_layout()
plt.savefig('model accuracy before and after data claning_new1.png')
plt.show()

# %% [markdown]
# ## Compare the model accuracy on the basis of before remove outliers and after remove outliers

# %%
# Get accuracy scores
before_scores = fit_score(models, X_train, X_test, y_train, y_test)
after_scores = fit_score_clean(models, X_train_clean, X_test_clean, y_train_clean, y_test_clean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Get accuracy scores
# ----> 2 before_scores = fit_score(models, X_train, X_test, y_train, y_test)
#       3 after_scores = fit_score_clean(models, X_train_clean, X_test_clean, y_train_clean, y_test_clean)
#
# Cell In[25], line 13, in fit_score(models, X_train, X_test, y_train, y_test)
#      11 np.random.seed(42)
#      12 model_scores = {}
# ---> 13 for name, model in models.items():
#      14     model.fit(X_train, y_train)
#      15     model_scores[name] = model.score(X_test, y_test)
#
# AttributeError: 'list' object has no attribute 'items'

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = list(before_scores.keys())
before = [before_scores[model] for model in labels]
after = [after_scores[model] for model in labels]

x = np.arange(len(labels))  # the label locations
width = 0.35  # width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, before, width, label='Before', color='red')
bars2 = ax.bar(x + width/2, after, width, label='After', color='green')

# Add some text for labels, title and axes ticks
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy: Before with outliers  vs After remove outliers')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# # Optionally, add labels on top of bars
# for i in range(len(labels)):
#     ax.text(x[i] - width/2, before[i] + 0.01, f"{before[i]:.2f}", ha='center')
#     ax.text(x[i] + width/2, after[i] + 0.01, f"{after[i]:.2f}", ha='center')

#plt.ylim(0, 1.1)  # make room for labels
#plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 labels = list(before_scores.keys())
#       5 before = [before_scores[model] for model in labels]
#       6 after = [after_scores[model] for model in labels]
#
# AttributeError: 'list' object has no attribute 'keys'
